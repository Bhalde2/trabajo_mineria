# %%
# Este sería un Jupyter Notebook completo con todo el EDA que mostré anteriormente
# Incluyendo:
# - Análisis de distribuciones
# - Correlaciones
# - Visualizaciones
# - Preprocesamiento inicial
